# %% [markdown]
# Activity 3.2 (A)

# %%
for i in range(5):
    for j in range(5):
        print("*", end="")
    print()

# %% [markdown]
# Activity 3.2 (B)

# %%
for i in range(1, 6):
    for j in range(i):
        print("*", end="")
    print()

# %% [markdown]
# Activity 3.2 (C)

# %%
for i in range(5, 0, -1):
    for j in range(i):
        print("*", end="")
    print()
