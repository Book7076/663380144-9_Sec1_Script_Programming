# %% [markdown]
# Activity 3.1 (A)

# %%
counter = 0
while counter < 5:
    print(counter)
    counter += 1

# %% [markdown]
# Activity 3.1 (B)

# %%
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Activity 3.1 (C)

# %%
for char in "hello":
    if char == 'l':
        print("Found 'l'")
        break
    print(char)
# Out:
# h
# e
# Found 'l'
